# %%
# !git clone --recurse-submodule https://github.com/CHeckingV/tracking_wo_bnw.git
# Out:
# Cloning into 'tracking_wo_bnw'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 1638 (delta 78), reused 86 (delta 34), pack-reused 1500
# Receiving objects: 100% (1638/1638), 6.01 MiB | 4.65 MiB/s, done.
# Resolving deltas: 100% (1055/1055), done.
# Submodule 'src/fpn' (https://github.com/timmeinhardt/FPN_Pytorch) registered for path 'src/fpn'
# Submodule 'src/frcnn' (https://github.com/phil-bergmann/pytorch-faster-rcnn) registered for path 'src/frcnn'
# Cloning into '/content/tracking_wo_bnw/src/fpn'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 429 (delta 21), reused 36 (delta 18), pack-reused 380
# Receiving objects: 100% (429/429), 298.45 KiB | 560.00 KiB/s, done.
# Resolving deltas: 100% (214/214), done.
# ...

# %%
# %cd /content/tracking_wo_bnw/
# Out:
# /content/tracking_wo_bnw

# %%
# !pip install -r requirements.txt
# !pip install -e src/fpn
# !pip install -e src/frcnn
# !pip install -e .
# !pip3 install torch torchvision
# !pip install https://download.pytorch.org/whl/cu90/torch-0.3.1-cp36-cp36m-linux_x86_64.whl
# Out:
# ...
#      |████████████████████████████████| 102kB 3.2MB/s
# ...
#      |████████████████████████████████| 430kB 8.7MB/s
# ...
#      |████████████████████████████████| 2.1MB 49.9MB/s
# ...
#      |████████████████████████████████| 9.7MB 17.4MB/s
# ...
#      |████████████████████████████████| 716kB 44.7MB/s
# ...
#      |████████████████████████████████| 71kB 7.4MB/s
# ...
#      |████████████████████████████████| 51kB 7.6MB/s
# ...
#      |████████████████████████████████| 92kB 11.6MB/s
# ...
#      |████████████████████████████████| 15.0MB 14.3MB/s
# ...
#      |████████████████████████████████| 61kB 8.8MB/s
# ...
#      |████████████████████████████████| 256kB 48.7MB/s
# ...
#      |████████████████████████████████| 17.3MB 475kB/s
# ...
#      |████████████████████████████████| 25.8MB 35.9MB/s
# ...
#      |████████████████████████████████| 10.1MB 39.7MB/s
# ...
#      |████████████████████████████████| 2.0MB 33.2MB/s
# ...
#      |████████████████████████████████| 1.1MB 39.1MB/s
# ...
#      |████████████████████████████████| 92kB 11.2MB/s
# ...

# %%
# %cd data/
# Out:
# /content/tracking_wo_bnw/data

# %%
#!pip install wget
#import wget 
#wget.download('https://motchallenge.net/data/MOT17Det.zip')
#wget.download('https://motchallenge.net/data/MOT16Labels.zip');
#wget.download('https://motchallenge.net/data/2DMOT2015.zip');
wget.download('https://motchallenge.net/data/MOT16-det-dpm-raw.zip');
wget.download('https://motchallenge.net/data/MOT17Labels.zip');
# !unzip -d MOT17Det MOT17Det.zip;
# !unzip -d 2DMOT2015 2DMOT2015.zip;
# !unzip -d MOT16-det-dpm-raw MOT16-det-dpm-raw.zip; 
# !unzip -d MOT17Labels MOT17Labels.zip;
# !unzip -d MOT16Labels MOT16Labels.zip;
# %rm *.zip
# %ls
# Out:
# Archive:  MOT17Det.zip
#   inflating: MOT17Det/test/MOT17-01/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-03/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-06/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-07/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-08/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-12/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-14/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-02/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-04/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-05/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-09/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-10/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-11/seqinfo.ini
#   inflating: MOT17Det/train/MOT17-13/seqinfo.ini
#   inflating: MOT17Det/test/MOT17-01/img1/000001.jpg
#   inflating: MOT17Det/test/MOT17-01/img1/000002.jpg
#   inflating: MOT17Det/test/MOT17-01/img1/000003.jpg
#   inflating: MOT17Det/test/MOT17-01/img1/000004.jpg
# ...

# %%
# %cd /content/tracking_wo_bnw/
# !wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb -O cuda-repo-ubuntu1604-9-0-local_9.0.88-1_amd64.deb
# %ll
# !apt-get remove cuda
! apt install ./cuda-repo-ubuntu1604-9-0-local_9.0.88-1_amd64.deb
# %ll
#!apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
#!apt-get install cuda
# Out:
# /content/tracking_wo_bnw
# --2019-10-30 14:37:56--  https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.189.146
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.189.146|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.0/secure/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64.deb?WZe4wR_xEWTgRwUiC96FY67szhOj1ufaqymQ4eAX8yr0wSI6H2CpLxtYiuIiqCeCeLHeJqLPjZn0vXU4WcLh71jHocIY2g9PKr5fU93l-w0FZBwuZXFBz8V5dEv2uASuByeavpY5LuXma9e49bhvov1zE-5X4Q0H_JZsYBaFKo3yYKsUIU0Bbh9Fje3t_mSo7JJ7EB4PzmdfHETL6B_C [following]
# ...

# %%
# !nvcc --version
# !lspci | grep -i nvidia
# !gcc --version
# !add-apt-repository ppa:graphics-drivers/ppa
# !apt install nvidia-384 nvidia-384-dev
# !apt-get install g++ freeglut3-dev build-essential libx11-dev libxmu-dev libxi-dev libglu1-mesa libglu1-mesa-dev
# !apt install gcc-6
# !apt install g++-6
# !wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda_9.0.176_384.81_linux-run
# !chmod +x cuda_9.0.176_384.81_linux-run 
# !./cuda_9.0.176_384.81_linux-run --override
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130
# /bin/bash: lspci: command not found
# gcc (Ubuntu 7.4.0-1ubuntu1~18.04.1) 7.4.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
#  Fresh drivers from upstream, currently shipping Nvidia.
#
# ## Current Status
#
# Current long-lived branch release: `nvidia-430` (430.40)
# Dropped support for Fermi series (https://nvidia.custhelp.com/app/answers/detail/a_id/4656)
#
# Old long-lived branch release: `nvidia-390` (390.129)
#
# For GF1xx GPUs use `nvidia-390` (390.129)
# For G8x, G9x and GT2xx GPUs use `nvidia-340` (340.107)
# For NV4x and G7x GPUs use `nvidia-304` (304.137) End-Of-Life!
#
# Support timeframes for Unix legacy GPU releases:
# ...

# %%
# %cd ..
# %ll
# !chmod +x cuda_9.0.176_384.81_linux-run
# !./cuda_9.0.176_384.81_linux-run --extract=$HOME
# Out:
# /
# total 96
# drwxr-xr-x   1 root 4096 Oct 25 16:51 bin/
# drwxr-xr-x   2 root 4096 Apr 24  2018 boot/
# drwxr-xr-x   1 root 4096 Oct 25 16:58 content/
# drwxr-xr-x   1 root 4096 Oct 28 15:52 datalab/
# drwxr-xr-x   5 root  440 Oct 30 13:40 dev/
# drwxr-xr-x   1 root 4096 Oct 30 13:40 etc/
# drwxr-xr-x   2 root 4096 Apr 24  2018 home/
# drwxr-xr-x   1 root 4096 Oct 25 16:53 lib/
# drwxr-xr-x   2 root 4096 Oct 25 16:44 lib32/
# drwxr-xr-x   2 root 4096 Aug  7 13:03 lib64/
# drwxr-xr-x   2 root 4096 Aug  7 13:02 media/
# drwxr-xr-x   2 root 4096 Aug  7 13:02 mnt/
# drwxr-xr-x   1 root 4096 Oct 30 13:40 opt/
# dr-xr-xr-x 109 root    0 Oct 30 13:40 proc/
# drwx------   1 root 4096 Oct 30 13:40 root/
# drwxr-xr-x   1 root 4096 Oct 25 16:51 run/
# drwxr-xr-x   1 root 4096 Oct 25 16:52 sbin/
# drwxr-xr-x   2 root 4096 Aug  7 13:02 srv/
# drwxr-xr-x   4 root 4096 Oct 28 15:50 swift/
# dr-xr-xr-x  12 root    0 Oct 30 13:50 sys/
# drwxr-xr-x   1 root 4096 Oct 28 15:47 tensorflow-2.0.0/
# ...

# %%
# %cd /content/tracking_wo_bnw/
# !sh src/fpn/fpn/make.sh
# !sh src/frcnn/frcnn/make.sh
# Out:
# /content/tracking_wo_bnw
# running build_ext
# cythoning model/utils/bbox.pyx to model/utils/bbox.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/tracking_wo_bnw/src/fpn/fpn/model/utils/bbox.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'model.utils.cython_bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/model
# creating build/temp.linux-x86_64-3.6/model/utils
# {'gcc': ['-Wno-cpp', '-Wno-unused-function']}
# ...

# %%
# %cd output
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1E0seC4zSdAsKUNScv4M0eAu7fG_v65_Q' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1E0seC4zSdAsKUNScv4M0eAu7fG_v65_Q" -O weights.zip && rm -rf /tmp/cookies.txt 
# !unzip weights.zip
# %rm weights.zip
# %ll
# %cd ..
# %pwd
# Out:
# /content/tracking_wo_bnw/output
# --2019-10-30 14:15:15--  https://docs.google.com/uc?export=download&confirm=fumf&id=1E0seC4zSdAsKUNScv4M0eAu7fG_v65_Q
# Resolving docs.google.com (docs.google.com)... 108.177.97.100, 108.177.97.113, 108.177.97.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.97.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-08-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/c662453dr5lo2673tl40hk4e5iviv5q4/1572444000000/02070254218378297827/*/1E0seC4zSdAsKUNScv4M0eAu7fG_v65_Q?e=download [following]
# ...
# --2019-10-30 14:15:16--  https://doc-14-08-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/c662453dr5lo2673tl40hk4e5iviv5q4/1572444000000/02070254218378297827/*/1E0seC4zSdAsKUNScv4M0eAu7fG_v65_Q?e=download
# Resolving doc-14-08-docs.googleusercontent.com (doc-14-08-docs.googleusercontent.com)... 64.233.188.132, 2404:6800:4008:c06::84
# ...

# %%
# !python experiments/scripts/test_tracktor.py
# Out:
# Traceback (most recent call last):
#   File "experiments/scripts/test_tracktor.py", line 16, in <module>
#     from tracktor.datasets.factory import Datasets
#   File "/content/tracking_wo_bnw/src/tracktor/datasets/factory.py", line 2, in <module>
#     from .mot_wrapper import MOT17_Wrapper, MOT19CVPR_Wrapper, MOT17LOWFPS_Wrapper
#   File "/content/tracking_wo_bnw/src/tracktor/datasets/mot_wrapper.py", line 4, in <module>
#     from .mot_sequence import MOT17_Sequence, MOT19CVPR_Sequence, MOT17LOWFPS_Sequence
#   File "/content/tracking_wo_bnw/src/tracktor/datasets/mot_sequence.py", line 12, in <module>
#     from frcnn.model import test
#   File "/content/tracking_wo_bnw/src/frcnn/frcnn/model/test.py", line 22, in <module>
#     from .nms_wrapper import nms
#   File "/content/tracking_wo_bnw/src/frcnn/frcnn/model/nms_wrapper.py", line 11, in <module>
#     from ..nms.pth_nms import pth_nms
#   File "/content/tracking_wo_bnw/src/frcnn/frcnn/nms/pth_nms.py", line 2, in <module>
# ...

# %%
# %cd ..
# Out:
# /content/tracking_wo_bnw
